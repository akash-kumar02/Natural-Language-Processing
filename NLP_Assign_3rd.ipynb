# %% [markdown]
# # **Assignment 3:**
#  Apply NER to identify entities such as names, organizations, and locations in a given
# text. Perform sentence segmentation on a paragraph and explain its importance in NLP tasks.
#
# **By Akash Kumar,**

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp=spacy.load('en_core_web_sm')

# %% [markdown]
# #Text Cleaning

# %%
text = """ In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the globe. Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention. These advancements have led to the rapid growth of fields like Machine Learning, Natural Language Processing, and Computer Vision.

In India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare, education, and finance. For example, hospitals in Bangalore and Delhi now use AI-powered diagnostic tools to detect diseases like cancer at an early stage. Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.

Education has also benefited from AI-driven platforms. Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets. Online learning platforms such as Coursera, edX, and Udemy provide personalized learning experiences by analyzing user behavior and recommending relevant courses. As a result, students from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality educational resources.

Despite these benefits, the rise of AI has raised several ethical and social concerns. Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement. In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.

Governments around the world are responding by introducing regulations and policies. The European Union proposed the AI Act, aiming to regulate high-risk AI applications, while the Government of India announced initiatives such as Digital India and National AI Strategy to promote responsible AI development. Policymakers believe that a balanced approach can foster innovation while protecting citizens' rights.

Looking ahead, the future of AI appears promising yet challenging. Researchers predict that AI will continue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare systems. However, collaboration between governments, private organizations, and academic institutions will be essential to address ethical challenges and ensure sustainable growth. Ultimately, AI is not just a technological revolution but a societal transformation that will shape the way humans live and work in the decades to come. """

# %%
stopwords=list(STOP_WORDS)

# %%
doc=nlp(text) #Applied tokenization

# %%
tokens=[token.text for token in doc]

# %%
print(tokens)
# Out:
# [' ', 'In', 'recent', 'years', ',', 'Artificial', 'Intelligence', '(', 'AI', ')', 'has', 'transformed', 'the', 'way', 'organizations', 'operate', 'across', 'the', 'globe', '.', 'Companies', 'such', 'as', 'Google', ',', 'Microsoft', ',', 'and', 'Amazon', 'have', 'invested', 'billions', 'of', 'dollars', 'into', 'research', 'and', 'development', 'to', 'improve', 'intelligent', 'systems', 'that', 'can', 'learn', 'from', 'data', 'and', 'make', 'decisions', 'with', 'minimal', 'human', 'intervention', '.', 'These', 'advancements', 'have', 'led', 'to', 'the', 'rapid', 'growth', 'of', 'fields', 'like', 'Machine', 'Learning', ',', 'Natural', 'Language', 'Processing', ',', 'and', 'Computer', 'Vision', '.', '\n\n', 'In', 'India', ',', 'the', 'adoption', 'of', 'AI', 'has', 'accelerated', 'significantly', ',', 'particularly', 'in', 'sectors', 'such', 'as', 'healthcare', ',', 'education', ',', 'and', 'finance', '.', 'For', 'example', ',', 'hospitals', 'in', 'Bangalore', 'and', 'Delhi', 'now', 'use', 'AI', '-', 'powered', 'diagnostic', 'tools', 'to', 'detect', 'diseases', 'like', 'cancer', 'at', 'an', 'early', 'stage', '.', 'Similarly', ',', 'banks', 'such', 'as', 'State', 'Bank', 'of', 'India', '(', 'SBI', ')', 'and', 'HDFC', 'Bank', 'have', 'deployed', 'chatbots', 'to', 'assist', 'customers', 'with', 'account', '-', 'related', 'queries', ',', 'improving', 'both', 'efficiency', 'and', 'user', 'satisfaction', '.', '\n\n', 'Education', 'has', 'also', 'benefited', 'from', 'AI', '-', 'driven', 'platforms', '.', 'Universities', 'like', 'IIT', 'Bombay', 'and', 'IIT', 'Delhi', 'are', 'incorporating', 'data', 'science', 'and', 'AI', 'courses', 'into', 'their', 'curricula', 'to', 'prepare', 'students', 'for', 'future', 'job', 'markets', '.', 'Online', 'learning', 'platforms', 'such', 'as', 'Coursera', ',', 'edX', ',', 'and', 'Udemy', 'provide', 'personalized', 'learning', 'experiences', 'by', 'analyzing', 'user', 'behavior', 'and', 'recommending', 'relevant', 'courses', '.', 'As', 'a', 'result', ',', 'students', 'from', 'remote', 'areas', 'of', 'Rajasthan', 'and', 'Uttar', 'Pradesh', 'now', 'have', 'access', 'to', 'high', '-', 'quality', 'educational', 'resources', '.', '\n\n', 'Despite', 'these', 'benefits', ',', 'the', 'rise', 'of', 'AI', 'has', 'raised', 'several', 'ethical', 'and', 'social', 'concerns', '.', 'Experts', 'from', 'organizations', 'like', 'the', 'World', 'Economic', 'Forum', '(', 'WEF', ')', 'and', 'UNESCO', 'have', 'warned', 'about', 'issues', 'related', 'to', 'data', 'privacy', ',', 'algorithmic', 'bias', ',', 'and', 'job', 'displacement', '.', 'In', '2023', ',', 'a', 'report', 'published', 'by', 'UNESCO', 'emphasized', 'the', 'need', 'for', 'transparent', 'and', 'fair', 'AI', 'systems', 'to', 'ensure', 'that', 'technology', 'benefits', 'society', 'as', 'a', 'whole', '.', '\n\n', 'Governments', 'around', 'the', 'world', 'are', 'responding', 'by', 'introducing', 'regulations', 'and', 'policies', '.', 'The', 'European', 'Union', 'proposed', 'the', 'AI', 'Act', ',', 'aiming', 'to', 'regulate', 'high', '-', 'risk', 'AI', 'applications', ',', 'while', 'the', 'Government', 'of', 'India', 'announced', 'initiatives', 'such', 'as', 'Digital', 'India', 'and', 'National', 'AI', 'Strategy', 'to', 'promote', 'responsible', 'AI', 'development', '.', 'Policymakers', 'believe', 'that', 'a', 'balanced', 'approach', 'can', 'foster', 'innovation', 'while', 'protecting', 'citizens', "'", 'rights', '.', '\n\n', 'Looking', 'ahead', ',', 'the', 'future', 'of', 'AI', 'appears', 'promising', 'yet', 'challenging', '.', 'Researchers', 'predict', 'that', 'AI', 'will', 'continue', 'to', 'evolve', ',', 'enabling', 'smarter', 'cities', ',', 'autonomous', 'vehicles', ',', 'and', 'advanced', 'healthcare', 'systems', '.', 'However', ',', 'collaboration', 'between', 'governments', ',', 'private', 'organizations', ',', 'and', 'academic', 'institutions', 'will', 'be', 'essential', 'to', 'address', 'ethical', 'challenges', 'and', 'ensure', 'sustainable', 'growth', '.', ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punctuation=punctuation + '\n'

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
word_frequencies={}
for word in doc:
  if word.text.lower() not in stopwords:
    if word.text.lower() not in punctuation:
      if word.text not in word_frequencies.keys():
        word_frequencies[word.text]=1
      else:
        word_frequencies[word.text]+=1

# %%
word_frequencies
# Out:
# {' ': 1,
#  'recent': 1,
#  'years': 1,
#  'Artificial': 1,
#  'Intelligence': 1,
#  'AI': 14,
#  'transformed': 1,
#  'way': 2,
#  'organizations': 3,
#  'operate': 1,
#  'globe': 1,
#  'Companies': 1,
#  'Google': 1,
#  'Microsoft': 1,
#  'Amazon': 1,
#  'invested': 1,
#  'billions': 1,
#  'dollars': 1,
#  'research': 1,
#  'development': 2,
#  'improve': 1,
#  'intelligent': 1,
#  'systems': 3,
#  'learn': 1,
#  'data': 3,
#  'decisions': 1,
#  'minimal': 1,
#  'human': 1,
#  'intervention': 1,
#  'advancements': 1,
#  'led': 1,
#  'rapid': 1,
#  'growth': 2,
#  'fields': 1,
#  'like': 4,
#  'Machine': 1,
#  'Learning': 1,
#  'Natural': 1,
#  'Language': 1,
#  'Processing': 1,
#  'Computer': 1,
#  'Vision': 1,
#  '\n\n': 5,
#  'India': 4,
#  'adoption': 1,
#  'accelerated': 1,
#  'significantly': 1,
#  'particularly': 1,
#  'sectors': 1,
#  'healthcare': 2,
#  'education': 1,
#  'finance': 1,
#  'example': 1,
#  'hospitals': 1,
#  'Bangalore': 1,
#  'Delhi': 2,
#  'use': 1,
#  'powered': 1,
#  'diagnostic': 1,
#  'tools': 1,
#  'detect': 1,
#  'diseases': 1,
#  'cancer': 1,
#  'early': 1,
#  'stage': 1,
#  'Similarly': 1,
#  'banks': 1,
#  'State': 1,
#  'Bank': 2,
#  'SBI': 1,
#  'HDFC': 1,
#  'deployed': 1,
#  'chatbots': 1,
#  'assist': 1,
#  'customers': 1,
#  'account': 1,
#  'related': 2,
#  'queries': 1,
#  'improving': 1,
#  'efficiency': 1,
#  'user': 2,
#  'satisfaction': 1,
#  'Education': 1,
#  'benefited': 1,
#  'driven': 1,
#  'platforms': 2,
#  'Universities': 1,
#  'IIT': 2,
#  'Bombay': 1,
#  'incorporating': 1,
#  'science': 1,
#  'courses': 2,
#  'curricula': 1,
#  'prepare': 1,
#  'students': 2,
#  'future': 2,
#  'job': 2,
#  'markets': 1,
#  'Online': 1,
#  'learning': 2,
#  'Coursera': 1,
#  'edX': 1,
#  'Udemy': 1,
#  'provide': 1,
#  'personalized': 1,
#  'experiences': 1,
#  'analyzing': 1,
#  'behavior': 1,
#  'recommending': 1,
#  'relevant': 1,
#  'result': 1,
#  'remote': 1,
#  'areas': 1,
#  'Rajasthan': 1,
#  'Uttar': 1,
#  'Pradesh': 1,
#  'access': 1,
#  'high': 2,
#  'quality': 1,
#  'educational': 1,
#  'resources': 1,
#  'Despite': 1,
#  'benefits': 2,
#  'rise': 1,
#  'raised': 1,
#  'ethical': 2,
#  'social': 1,
#  'concerns': 1,
#  'Experts': 1,
#  'World': 1,
#  'Economic': 1,
#  'Forum': 1,
#  'WEF': 1,
#  'UNESCO': 2,
#  'warned': 1,
#  'issues': 1,
#  'privacy': 1,
#  'algorithmic': 1,
#  'bias': 1,
#  'displacement': 1,
#  '2023': 1,
#  'report': 1,
#  'published': 1,
#  'emphasized': 1,
#  'need': 1,
#  'transparent': 1,
#  'fair': 1,
#  'ensure': 2,
#  'technology': 1,
#  'society': 1,
#  'Governments': 1,
#  'world': 1,
#  'responding': 1,
#  'introducing': 1,
#  'regulations': 1,
#  'policies': 1,
#  'European': 1,
#  'Union': 1,
#  'proposed': 1,
#  'Act': 1,
#  'aiming': 1,
#  'regulate': 1,
#  'risk': 1,
#  'applications': 1,
#  'Government': 1,
#  'announced': 1,
#  'initiatives': 1,
#  'Digital': 1,
#  'National': 1,
#  'Strategy': 1,
#  'promote': 1,
#  'responsible': 1,
#  'Policymakers': 1,
#  'believe': 1,
#  'balanced': 1,
#  'approach': 1,
#  'foster': 1,
#  'innovation': 1,
#  'protecting': 1,
#  'citizens': 1,
#  'rights': 1,
#  'Looking': 1,
#  'ahead': 1,
#  'appears': 1,
#  'promising': 1,
#  'challenging': 1,
#  'Researchers': 1,
#  'predict': 1,
#  'continue': 1,
#  'evolve': 1,
#  'enabling': 1,
#  'smarter': 1,
#  'cities': 1,
#  'autonomous': 1,
#  'vehicles': 1,
#  'advanced': 1,
#  'collaboration': 1,
#  'governments': 1,
#  'private': 1,
#  'academic': 1,
#  'institutions': 1,
#  'essential': 1,
#  'address': 1,
#  'challenges': 1,
#  'sustainable': 1,
#  'Ultimately': 1,
#  'technological': 1,
#  'revolution': 1,
#  'societal': 1,
#  'transformation': 1,
#  'shape': 1,
#  'humans': 1,
#  'live': 1,
#  'work': 1,
#  'decades': 1,
#  'come': 1}

# %%
max_frequency=max(word_frequencies.values())

# %%
max_frequency
# Out:
# 14

# %%
for word in word_frequencies.keys():
  word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
print(word_frequencies)
# Out:
# {' ': 0.07142857142857142, 'recent': 0.07142857142857142, 'years': 0.07142857142857142, 'Artificial': 0.07142857142857142, 'Intelligence': 0.07142857142857142, 'AI': 1.0, 'transformed': 0.07142857142857142, 'way': 0.14285714285714285, 'organizations': 0.21428571428571427, 'operate': 0.07142857142857142, 'globe': 0.07142857142857142, 'Companies': 0.07142857142857142, 'Google': 0.07142857142857142, 'Microsoft': 0.07142857142857142, 'Amazon': 0.07142857142857142, 'invested': 0.07142857142857142, 'billions': 0.07142857142857142, 'dollars': 0.07142857142857142, 'research': 0.07142857142857142, 'development': 0.14285714285714285, 'improve': 0.07142857142857142, 'intelligent': 0.07142857142857142, 'systems': 0.21428571428571427, 'learn': 0.07142857142857142, 'data': 0.21428571428571427, 'decisions': 0.07142857142857142, 'minimal': 0.07142857142857142, 'human': 0.07142857142857142, 'intervention': 0.07142857142857142, 'advancements': 0.07142857142857142, 'led': 0.07142857142857142, 'rapid': 0.07142857142857142, 'growth': 0.14285714285714285, 'fields': 0.07142857142857142, 'like': 0.2857142857142857, 'Machine': 0.07142857142857142, 'Learning': 0.07142857142857142, 'Natural': 0.07142857142857142, 'Language': 0.07142857142857142, 'Processing': 0.07142857142857142, 'Computer': 0.07142857142857142, 'Vision': 0.07142857142857142, '\n\n': 0.35714285714285715, 'India': 0.2857142857142857, 'adoption': 0.07142857142857142, 'accelerated': 0.07142857142857142, 'significantly': 0.07142857142857142, 'particularly': 0.07142857142857142, 'sectors': 0.07142857142857142, 'healthcare': 0.14285714285714285, 'education': 0.07142857142857142, 'finance': 0.07142857142857142, 'example': 0.07142857142857142, 'hospitals': 0.07142857142857142, 'Bangalore': 0.07142857142857142, 'Delhi': 0.14285714285714285, 'use': 0.07142857142857142, 'powered': 0.07142857142857142, 'diagnostic': 0.07142857142857142, 'tools': 0.07142857142857142, 'detect': 0.07142857142857142, 'diseases': 0.07142857142857142, 'cancer': 0.07142857142857142, 'early': 0.07142857142857142, 'stage': 0.07142857142857142, 'Similarly': 0.07142857142857142, 'banks': 0.07142857142857142, 'State': 0.07142857142857142, 'Bank': 0.14285714285714285, 'SBI': 0.07142857142857142, 'HDFC': 0.07142857142857142, 'deployed': 0.07142857142857142, 'chatbots': 0.07142857142857142, 'assist': 0.07142857142857142, 'customers': 0.07142857142857142, 'account': 0.07142857142857142, 'related': 0.14285714285714285, 'queries': 0.07142857142857142, 'improving': 0.07142857142857142, 'efficiency': 0.07142857142857142, 'user': 0.14285714285714285, 'satisfaction': 0.07142857142857142, 'Education': 0.07142857142857142, 'benefited': 0.07142857142857142, 'driven': 0.07142857142857142, 'platforms': 0.14285714285714285, 'Universities': 0.07142857142857142, 'IIT': 0.14285714285714285, 'Bombay': 0.07142857142857142, 'incorporating': 0.07142857142857142, 'science': 0.07142857142857142, 'courses': 0.14285714285714285, 'curricula': 0.07142857142857142, 'prepare': 0.07142857142857142, 'students': 0.14285714285714285, 'future': 0.14285714285714285, 'job': 0.14285714285714285, 'markets': 0.07142857142857142, 'Online': 0.07142857142857142, 'learning': 0.14285714285714285, 'Coursera': 0.07142857142857142, 'edX': 0.07142857142857142, 'Udemy': 0.07142857142857142, 'provide': 0.07142857142857142, 'personalized': 0.07142857142857142, 'experiences': 0.07142857142857142, 'analyzing': 0.07142857142857142, 'behavior': 0.07142857142857142, 'recommending': 0.07142857142857142, 'relevant': 0.07142857142857142, 'result': 0.07142857142857142, 'remote': 0.07142857142857142, 'areas': 0.07142857142857142, 'Rajasthan': 0.07142857142857142, 'Uttar': 0.07142857142857142, 'Pradesh': 0.07142857142857142, 'access': 0.07142857142857142, 'high': 0.14285714285714285, 'quality': 0.07142857142857142, 'educational': 0.07142857142857142, 'resources': 0.07142857142857142, 'Despite': 0.07142857142857142, 'benefits': 0.14285714285714285, 'rise': 0.07142857142857142, 'raised': 0.0 ...

# %% [markdown]
# #Sentence Tokenization

# %%
sentence_tokens=[sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [ In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the globe., Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention., These advancements have led to the rapid growth of fields like Machine Learning, Natural Language Processing, and Computer Vision.
#
# , In India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare, education, and finance., For example, hospitals in Bangalore and Delhi now use AI-powered diagnostic tools to detect diseases like cancer at an early stage., Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.
#
# , Education has also benefited from AI-driven platforms., Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets., Online learning platforms such as Coursera, edX, and Udemy provide personalized learning experiences by analyzing user behavior and recommending relevant courses., As a result, students from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality educational resources.
#
# , Despite these benefits, the rise of AI has raised several ethical and social concerns., Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement., In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.
#
# , Governments around the world are responding by introducing regulations and policies., The European Union proposed the AI Act, aiming to regulate high-risk AI applications, while the Government of India announced initiatives such as Digital India and National AI Strategy to promote responsible AI development., Policymakers believe that a balanced approach can foster innovation while protecting citizens' rights.
#
# , Looking ahead, the future of AI appears promising yet challenging., Researchers predict that AI will continue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare systems., However, collaboration between governments, private organizations, and academic institutions will be essential to address ethical challenges and ensure sustainable growth., Ultimately, AI is not just a technological revolution but a societal transformation that will shape the way humans live and work in the decades to come.]

# %%
len(sentence_tokens)
# Out:
# 20

# %%
sentence_score={}
for sent in sentence_tokens:
  for word in sent:
    if word.text.lower() in word_frequencies.keys():
      if sent not in sentence_score.keys():
        sentence_score[sent]=word_frequencies[word.text.lower()]
      else:
        sentence_score[sent]+=word_frequencies[word.text.lower()]

# %%
print(sentence_score)
# Out:
# { In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the globe.: 0.7857142857142856, Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention.: 1.357142857142857, These advancements have led to the rapid growth of fields like Machine Learning, Natural Language Processing, and Computer Vision.
#
# : 1.2142857142857142, In India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare, education, and finance.: 0.6428571428571428, For example, hospitals in Bangalore and Delhi now use AI-powered diagnostic tools to detect diseases like cancer at an early stage.: 1.0714285714285712, Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.
#
# : 1.357142857142857, Education has also benefited from AI-driven platforms.: 0.3571428571428571, Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets.: 1.4285714285714282, Online learning platforms such as Coursera, edX, and Udemy provide personalized learning experiences by analyzing user behavior and recommending relevant courses.: 1.214285714285714, As a result, students from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality educational resources.
#
# : 1.1428571428571428, Despite these benefits, the rise of AI has raised several ethical and social concerns.: 0.5714285714285714, Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement.: 1.4999999999999996, In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.
#
# : 1.4999999999999998, Governments around the world are responding by introducing regulations and policies.: 0.4285714285714285, The European Union proposed the AI Act, aiming to regulate high-risk AI applications, while the Government of India announced initiatives such as Digital India and National AI Strategy to promote responsible AI development.: 0.9285714285714284, Policymakers believe that a balanced approach can foster innovation while protecting citizens' rights.
#
# : 0.9285714285714284, Looking ahead, the future of AI appears promising yet challenging.: 0.4285714285714285, Researchers predict that AI will continue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare systems.: 0.9999999999999999, However, collaboration between governments, private organizations, and academic institutions will be essential to address ethical challenges and ensure sustainable growth.: 1.2857142857142854, Ultimately, AI is not just a technological revolution but a societal transformation that will shape the way humans live and work in the decades to come.: 0.857142857142857}

# %% [markdown]
# #Getting the summary

# %%
from heapq import nlargest
summary=nlargest(n=int(select_length),iterable=sentence_score,key=sentence_score.get)

# %%
print(summary)
# Out:
# [In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.
#
# , Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement., Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets., Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention., Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.
#
# ]

# %%
#Combine these sentences together
final_summary=[word.text for word in summary]

# %%
final_summary
# Out:
# ['In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.\n\n',
#  'Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement.',
#  'Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets.',
#  'Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention.',
#  'Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.\n\n']

# %%
summary=' '.join(final_summary)

# %%
print(summary)
# Out:
# In 2023, a report published by UNESCO emphasized the need for transparent and fair AI systems to ensure that technology benefits society as a whole.
#
#  Experts from organizations like the World Economic Forum (WEF) and UNESCO have warned about issues related to data privacy, algorithmic bias, and job displacement. Universities like IIT Bombay and IIT Delhi are incorporating data science and AI courses into their curricula to prepare students for future job markets. Companies such as Google, Microsoft, and Amazon have invested billions of dollars into research and development to improve intelligent systems that can learn from data and make decisions with minimal human intervention. Similarly, banks such as State Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with account-related queries, improving both efficiency and user satisfaction.

# %%
#Comaparing
len(text) #length of original text
# Out:
# 2748

# %%
len(summary) #length of summary
# Out:
# 877

# %% [markdown]
# # Text Summarization on Pdf

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import PyPDF2

# %%
f=open('/content/AI_Text.pdf','rb')
pdf_text=[]
pdf_reader=PyPDF2.PdfReader(f)
for p in range(len(pdf_reader.pages)):
    page=pdf_reader.pages[p]
    pdf_text.append(page.extract_text())
f.close()

# %%
f=pdf_text
f
# Out:
# ["In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the\nglobe. Companies such as Google, Microsoft, and Amazon have invested billions of dollars into\nresearch and development to improve intelligent systems that can learn from data and make\ndecisions with minimal human intervention. These advancements have led to the rapid growth of\nfields like Machine Learning, Natural Language Processing, and Computer Vision.\nIn India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare,\neducation, and finance. For example, hospitals in Bangalore and Delhi now use AI-powered\ndiagnostic tools to detect diseases like cancer at an early stage. Similarly, banks such as State\nBank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with\naccount-related queries, improving both efficiency and user satisfaction.\nEducation has also benefited from AI-driven platforms. Universities like IIT Bombay and IIT Delhi\nare incorporating data science and AI courses into their curricula to prepare students for future job\nmarkets. Online learning platforms such as Coursera, edX, and Udemy provide personalized\nlearning experiences by analyzing user behavior and recommending relevant courses. As a result,\nstudents from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality\neducational resources.\nDespite these benefits, the rise of AI has raised several ethical and social concerns. Experts from\norganizations like the World Economic Forum (WEF) and UNESCO have warned about issues\nrelated to data privacy, algorithmic bias, and job displacement. In 2023, a report published by\nUNESCO emphasized the need for transparent and fair AI systems to ensure that technology\nbenefits society as a whole.\nGovernments around the world are responding by introducing regulations and policies. The\nEuropean Union proposed the AI Act, aiming to regulate high-risk AI applications, while the\nGovernment of India announced initiatives such as Digital India and National AI Strategy to promote\nresponsible AI development. Policymakers believe that a balanced approach can foster innovation\nwhile protecting citizens' rights.\nLooking ahead, the future of AI appears promising yet challenging. Researchers predict that AI will\ncontinue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare\nsystems. However, collaboration between governments, private organizations, and academic\ninstitutions will be essential to address ethical challenges and ensure sustainable growth.\nUltimately, AI is not just a technological revolution but a societal transformation that will shape the\nway humans live and work in the decades to come.\n"]

# %% [markdown]
# #Text Cleaning

# %%
stopwords=list(STOP_WORDS)

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(' '.join(f)) #Applied tokenization

# %%
tokens=[token.text for token in doc]

# %%
print(tokens)
# Out:
# ['In', 'recent', 'years', ',', 'Artificial', 'Intelligence', '(', 'AI', ')', 'has', 'transformed', 'the', 'way', 'organizations', 'operate', 'across', 'the', '\n', 'globe', '.', 'Companies', 'such', 'as', 'Google', ',', 'Microsoft', ',', 'and', 'Amazon', 'have', 'invested', 'billions', 'of', 'dollars', 'into', '\n', 'research', 'and', 'development', 'to', 'improve', 'intelligent', 'systems', 'that', 'can', 'learn', 'from', 'data', 'and', 'make', '\n', 'decisions', 'with', 'minimal', 'human', 'intervention', '.', 'These', 'advancements', 'have', 'led', 'to', 'the', 'rapid', 'growth', 'of', '\n', 'fields', 'like', 'Machine', 'Learning', ',', 'Natural', 'Language', 'Processing', ',', 'and', 'Computer', 'Vision', '.', '\n', 'In', 'India', ',', 'the', 'adoption', 'of', 'AI', 'has', 'accelerated', 'significantly', ',', 'particularly', 'in', 'sectors', 'such', 'as', 'healthcare', ',', '\n', 'education', ',', 'and', 'finance', '.', 'For', 'example', ',', 'hospitals', 'in', 'Bangalore', 'and', 'Delhi', 'now', 'use', 'AI', '-', 'powered', '\n', 'diagnostic', 'tools', 'to', 'detect', 'diseases', 'like', 'cancer', 'at', 'an', 'early', 'stage', '.', 'Similarly', ',', 'banks', 'such', 'as', 'State', '\n', 'Bank', 'of', 'India', '(', 'SBI', ')', 'and', 'HDFC', 'Bank', 'have', 'deployed', 'chatbots', 'to', 'assist', 'customers', 'with', '\n', 'account', '-', 'related', 'queries', ',', 'improving', 'both', 'efficiency', 'and', 'user', 'satisfaction', '.', '\n', 'Education', 'has', 'also', 'benefited', 'from', 'AI', '-', 'driven', 'platforms', '.', 'Universities', 'like', 'IIT', 'Bombay', 'and', 'IIT', 'Delhi', '\n', 'are', 'incorporating', 'data', 'science', 'and', 'AI', 'courses', 'into', 'their', 'curricula', 'to', 'prepare', 'students', 'for', 'future', 'job', '\n', 'markets', '.', 'Online', 'learning', 'platforms', 'such', 'as', 'Coursera', ',', 'edX', ',', 'and', 'Udemy', 'provide', 'personalized', '\n', 'learning', 'experiences', 'by', 'analyzing', 'user', 'behavior', 'and', 'recommending', 'relevant', 'courses', '.', 'As', 'a', 'result', ',', '\n', 'students', 'from', 'remote', 'areas', 'of', 'Rajasthan', 'and', 'Uttar', 'Pradesh', 'now', 'have', 'access', 'to', 'high', '-', 'quality', '\n', 'educational', 'resources', '.', '\n', 'Despite', 'these', 'benefits', ',', 'the', 'rise', 'of', 'AI', 'has', 'raised', 'several', 'ethical', 'and', 'social', 'concerns', '.', 'Experts', 'from', '\n', 'organizations', 'like', 'the', 'World', 'Economic', 'Forum', '(', 'WEF', ')', 'and', 'UNESCO', 'have', 'warned', 'about', 'issues', '\n', 'related', 'to', 'data', 'privacy', ',', 'algorithmic', 'bias', ',', 'and', 'job', 'displacement', '.', 'In', '2023', ',', 'a', 'report', 'published', 'by', '\n', 'UNESCO', 'emphasized', 'the', 'need', 'for', 'transparent', 'and', 'fair', 'AI', 'systems', 'to', 'ensure', 'that', 'technology', '\n', 'benefits', 'society', 'as', 'a', 'whole', '.', '\n', 'Governments', 'around', 'the', 'world', 'are', 'responding', 'by', 'introducing', 'regulations', 'and', 'policies', '.', 'The', '\n', 'European', 'Union', 'proposed', 'the', 'AI', 'Act', ',', 'aiming', 'to', 'regulate', 'high', '-', 'risk', 'AI', 'applications', ',', 'while', 'the', '\n', 'Government', 'of', 'India', 'announced', 'initiatives', 'such', 'as', 'Digital', 'India', 'and', 'National', 'AI', 'Strategy', 'to', 'promote', '\n', 'responsible', 'AI', 'development', '.', 'Policymakers', 'believe', 'that', 'a', 'balanced', 'approach', 'can', 'foster', 'innovation', '\n', 'while', 'protecting', 'citizens', "'", 'rights', '.', '\n', 'Looking', 'ahead', ',', 'the', 'future', 'of', 'AI', 'appears', 'promising', 'yet', 'challenging', '.', 'Researchers', 'predict', 'that', 'AI', 'will', '\n', 'continue', 'to', 'evolve', ',', 'enabling', 'smarter', 'cities', ',', 'autonomous', 'vehicles', ',', 'and', 'advanced', 'healthcare', '\n', 'systems', '.', 'However', ',', 'collaboration', 'between', 'governments', ',', 'private', 'organizations', ',', 'and', 'academic', '\n', 'i ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
punctuation=punctuation + '\n'

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n\n'

# %%
word_frequencies={}
for word in doc:
  if word.text.lower() not in stopwords:
    if word.text.lower() not in punctuation:
      if word.text not in word_frequencies.keys():
        word_frequencies[word.text]=1
      else:
        word_frequencies[word.text]+=1

# %%
word_frequencies
# Out:
# {'recent': 1,
#  'years': 1,
#  'Artificial': 1,
#  'Intelligence': 1,
#  'AI': 14,
#  'transformed': 1,
#  'way': 2,
#  'organizations': 3,
#  'operate': 1,
#  'globe': 1,
#  'Companies': 1,
#  'Google': 1,
#  'Microsoft': 1,
#  'Amazon': 1,
#  'invested': 1,
#  'billions': 1,
#  'dollars': 1,
#  'research': 1,
#  'development': 2,
#  'improve': 1,
#  'intelligent': 1,
#  'systems': 3,
#  'learn': 1,
#  'data': 3,
#  'decisions': 1,
#  'minimal': 1,
#  'human': 1,
#  'intervention': 1,
#  'advancements': 1,
#  'led': 1,
#  'rapid': 1,
#  'growth': 2,
#  'fields': 1,
#  'like': 4,
#  'Machine': 1,
#  'Learning': 1,
#  'Natural': 1,
#  'Language': 1,
#  'Processing': 1,
#  'Computer': 1,
#  'Vision': 1,
#  'India': 4,
#  'adoption': 1,
#  'accelerated': 1,
#  'significantly': 1,
#  'particularly': 1,
#  'sectors': 1,
#  'healthcare': 2,
#  'education': 1,
#  'finance': 1,
#  'example': 1,
#  'hospitals': 1,
#  'Bangalore': 1,
#  'Delhi': 2,
#  'use': 1,
#  'powered': 1,
#  'diagnostic': 1,
#  'tools': 1,
#  'detect': 1,
#  'diseases': 1,
#  'cancer': 1,
#  'early': 1,
#  'stage': 1,
#  'Similarly': 1,
#  'banks': 1,
#  'State': 1,
#  'Bank': 2,
#  'SBI': 1,
#  'HDFC': 1,
#  'deployed': 1,
#  'chatbots': 1,
#  'assist': 1,
#  'customers': 1,
#  'account': 1,
#  'related': 2,
#  'queries': 1,
#  'improving': 1,
#  'efficiency': 1,
#  'user': 2,
#  'satisfaction': 1,
#  'Education': 1,
#  'benefited': 1,
#  'driven': 1,
#  'platforms': 2,
#  'Universities': 1,
#  'IIT': 2,
#  'Bombay': 1,
#  'incorporating': 1,
#  'science': 1,
#  'courses': 2,
#  'curricula': 1,
#  'prepare': 1,
#  'students': 2,
#  'future': 2,
#  'job': 2,
#  'markets': 1,
#  'Online': 1,
#  'learning': 2,
#  'Coursera': 1,
#  'edX': 1,
#  'Udemy': 1,
#  'provide': 1,
#  'personalized': 1,
#  'experiences': 1,
#  'analyzing': 1,
#  'behavior': 1,
#  'recommending': 1,
#  'relevant': 1,
#  'result': 1,
#  'remote': 1,
#  'areas': 1,
#  'Rajasthan': 1,
#  'Uttar': 1,
#  'Pradesh': 1,
#  'access': 1,
#  'high': 2,
#  'quality': 1,
#  'educational': 1,
#  'resources': 1,
#  'Despite': 1,
#  'benefits': 2,
#  'rise': 1,
#  'raised': 1,
#  'ethical': 2,
#  'social': 1,
#  'concerns': 1,
#  'Experts': 1,
#  'World': 1,
#  'Economic': 1,
#  'Forum': 1,
#  'WEF': 1,
#  'UNESCO': 2,
#  'warned': 1,
#  'issues': 1,
#  'privacy': 1,
#  'algorithmic': 1,
#  'bias': 1,
#  'displacement': 1,
#  '2023': 1,
#  'report': 1,
#  'published': 1,
#  'emphasized': 1,
#  'need': 1,
#  'transparent': 1,
#  'fair': 1,
#  'ensure': 2,
#  'technology': 1,
#  'society': 1,
#  'Governments': 1,
#  'world': 1,
#  'responding': 1,
#  'introducing': 1,
#  'regulations': 1,
#  'policies': 1,
#  'European': 1,
#  'Union': 1,
#  'proposed': 1,
#  'Act': 1,
#  'aiming': 1,
#  'regulate': 1,
#  'risk': 1,
#  'applications': 1,
#  'Government': 1,
#  'announced': 1,
#  'initiatives': 1,
#  'Digital': 1,
#  'National': 1,
#  'Strategy': 1,
#  'promote': 1,
#  'responsible': 1,
#  'Policymakers': 1,
#  'believe': 1,
#  'balanced': 1,
#  'approach': 1,
#  'foster': 1,
#  'innovation': 1,
#  'protecting': 1,
#  'citizens': 1,
#  'rights': 1,
#  'Looking': 1,
#  'ahead': 1,
#  'appears': 1,
#  'promising': 1,
#  'challenging': 1,
#  'Researchers': 1,
#  'predict': 1,
#  'continue': 1,
#  'evolve': 1,
#  'enabling': 1,
#  'smarter': 1,
#  'cities': 1,
#  'autonomous': 1,
#  'vehicles': 1,
#  'advanced': 1,
#  'collaboration': 1,
#  'governments': 1,
#  'private': 1,
#  'academic': 1,
#  'institutions': 1,
#  'essential': 1,
#  'address': 1,
#  'challenges': 1,
#  'sustainable': 1,
#  'Ultimately': 1,
#  'technological': 1,
#  'revolution': 1,
#  'societal': 1,
#  'transformation': 1,
#  'shape': 1,
#  'humans': 1,
#  'live': 1,
#  'work': 1,
#  'decades': 1,
#  'come': 1}

# %%
max_frequency=max(word_frequencies.values())

# %%
max_frequency
# Out:
# 14

# %%
for word in word_frequencies.keys():
  word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
print(word_frequencies)
# Out:
# {'recent': 0.07142857142857142, 'years': 0.07142857142857142, 'Artificial': 0.07142857142857142, 'Intelligence': 0.07142857142857142, 'AI': 1.0, 'transformed': 0.07142857142857142, 'way': 0.14285714285714285, 'organizations': 0.21428571428571427, 'operate': 0.07142857142857142, 'globe': 0.07142857142857142, 'Companies': 0.07142857142857142, 'Google': 0.07142857142857142, 'Microsoft': 0.07142857142857142, 'Amazon': 0.07142857142857142, 'invested': 0.07142857142857142, 'billions': 0.07142857142857142, 'dollars': 0.07142857142857142, 'research': 0.07142857142857142, 'development': 0.14285714285714285, 'improve': 0.07142857142857142, 'intelligent': 0.07142857142857142, 'systems': 0.21428571428571427, 'learn': 0.07142857142857142, 'data': 0.21428571428571427, 'decisions': 0.07142857142857142, 'minimal': 0.07142857142857142, 'human': 0.07142857142857142, 'intervention': 0.07142857142857142, 'advancements': 0.07142857142857142, 'led': 0.07142857142857142, 'rapid': 0.07142857142857142, 'growth': 0.14285714285714285, 'fields': 0.07142857142857142, 'like': 0.2857142857142857, 'Machine': 0.07142857142857142, 'Learning': 0.07142857142857142, 'Natural': 0.07142857142857142, 'Language': 0.07142857142857142, 'Processing': 0.07142857142857142, 'Computer': 0.07142857142857142, 'Vision': 0.07142857142857142, 'India': 0.2857142857142857, 'adoption': 0.07142857142857142, 'accelerated': 0.07142857142857142, 'significantly': 0.07142857142857142, 'particularly': 0.07142857142857142, 'sectors': 0.07142857142857142, 'healthcare': 0.14285714285714285, 'education': 0.07142857142857142, 'finance': 0.07142857142857142, 'example': 0.07142857142857142, 'hospitals': 0.07142857142857142, 'Bangalore': 0.07142857142857142, 'Delhi': 0.14285714285714285, 'use': 0.07142857142857142, 'powered': 0.07142857142857142, 'diagnostic': 0.07142857142857142, 'tools': 0.07142857142857142, 'detect': 0.07142857142857142, 'diseases': 0.07142857142857142, 'cancer': 0.07142857142857142, 'early': 0.07142857142857142, 'stage': 0.07142857142857142, 'Similarly': 0.07142857142857142, 'banks': 0.07142857142857142, 'State': 0.07142857142857142, 'Bank': 0.14285714285714285, 'SBI': 0.07142857142857142, 'HDFC': 0.07142857142857142, 'deployed': 0.07142857142857142, 'chatbots': 0.07142857142857142, 'assist': 0.07142857142857142, 'customers': 0.07142857142857142, 'account': 0.07142857142857142, 'related': 0.14285714285714285, 'queries': 0.07142857142857142, 'improving': 0.07142857142857142, 'efficiency': 0.07142857142857142, 'user': 0.14285714285714285, 'satisfaction': 0.07142857142857142, 'Education': 0.07142857142857142, 'benefited': 0.07142857142857142, 'driven': 0.07142857142857142, 'platforms': 0.14285714285714285, 'Universities': 0.07142857142857142, 'IIT': 0.14285714285714285, 'Bombay': 0.07142857142857142, 'incorporating': 0.07142857142857142, 'science': 0.07142857142857142, 'courses': 0.14285714285714285, 'curricula': 0.07142857142857142, 'prepare': 0.07142857142857142, 'students': 0.14285714285714285, 'future': 0.14285714285714285, 'job': 0.14285714285714285, 'markets': 0.07142857142857142, 'Online': 0.07142857142857142, 'learning': 0.14285714285714285, 'Coursera': 0.07142857142857142, 'edX': 0.07142857142857142, 'Udemy': 0.07142857142857142, 'provide': 0.07142857142857142, 'personalized': 0.07142857142857142, 'experiences': 0.07142857142857142, 'analyzing': 0.07142857142857142, 'behavior': 0.07142857142857142, 'recommending': 0.07142857142857142, 'relevant': 0.07142857142857142, 'result': 0.07142857142857142, 'remote': 0.07142857142857142, 'areas': 0.07142857142857142, 'Rajasthan': 0.07142857142857142, 'Uttar': 0.07142857142857142, 'Pradesh': 0.07142857142857142, 'access': 0.07142857142857142, 'high': 0.14285714285714285, 'quality': 0.07142857142857142, 'educational': 0.07142857142857142, 'resources': 0.07142857142857142, 'Despite': 0.07142857142857142, 'benefits': 0.14285714285714285, 'rise': 0.07142857142857142, 'raised': 0.07142857142857142, 'ethical': 0.14285714285714285, 'soci ...

# %% [markdown]
# #Sentence Tokenization

# %%
sentence_tokens=[sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the
# globe., Companies such as Google, Microsoft, and Amazon have invested billions of dollars into
# research and development to improve intelligent systems that can learn from data and make
# decisions with minimal human intervention., These advancements have led to the rapid growth of
# fields like Machine Learning, Natural Language Processing, and Computer Vision.
# , In India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare,
# education, and finance., For example, hospitals in Bangalore and Delhi now use AI-powered
# diagnostic tools to detect diseases like cancer at an early stage., Similarly, banks such as State
# Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with
# account-related queries, improving both efficiency and user satisfaction.
# , Education has also benefited from AI-driven platforms., Universities like IIT Bombay and IIT Delhi
# are incorporating data science and AI courses into their curricula to prepare students for future job
# markets., Online learning platforms such as Coursera, edX, and Udemy provide personalized
# learning experiences by analyzing user behavior and recommending relevant courses., As a result,
# students from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality
# educational resources.
# , Despite these benefits, the rise of AI has raised several ethical and social concerns., Experts from
# organizations like the World Economic Forum (WEF) and UNESCO have warned about issues
# related to data privacy, algorithmic bias, and job displacement., In 2023, a report published by
# UNESCO emphasized the need for transparent and fair AI systems to ensure that technology
# benefits society as a whole.
# , Governments around the world are responding by introducing regulations and policies., The
# European Union proposed the AI Act, aiming to regulate high-risk AI applications, while the
# Government of India announced initiatives such as Digital India and National AI Strategy to promote
# responsible AI development., Policymakers believe that a balanced approach can foster innovation
# while protecting citizens' rights.
# , Looking ahead, the future of AI appears promising yet challenging., Researchers predict that AI will
# continue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare
# systems., However, collaboration between governments, private organizations, and academic
# institutions will be essential to address ethical challenges and ensure sustainable growth.
# , Ultimately, AI is not just a technological revolution but a societal transformation that will shape the
# way humans live and work in the decades to come.
# ]

# %%
len(sentence_tokens)
# Out:
# 20

# %%
sentence_score={}
for sent in sentence_tokens:
  for word in sent:
    if word.text.lower() in word_frequencies.keys():
      if sent not in sentence_score.keys():
        sentence_score[sent]=word_frequencies[word.text.lower()]
      else:
        sentence_score[sent]+=word_frequencies[word.text.lower()]

# %%
print(sentence_score)
# Out:
# {In recent years, Artificial Intelligence (AI) has transformed the way organizations operate across the
# globe.: 0.7142857142857142, Companies such as Google, Microsoft, and Amazon have invested billions of dollars into
# research and development to improve intelligent systems that can learn from data and make
# decisions with minimal human intervention.: 1.357142857142857, These advancements have led to the rapid growth of
# fields like Machine Learning, Natural Language Processing, and Computer Vision.
# : 0.857142857142857, In India, the adoption of AI has accelerated significantly, particularly in sectors such as healthcare,
# education, and finance.: 0.6428571428571428, For example, hospitals in Bangalore and Delhi now use AI-powered
# diagnostic tools to detect diseases like cancer at an early stage.: 1.0714285714285712, Similarly, banks such as State
# Bank of India (SBI) and HDFC Bank have deployed chatbots to assist customers with
# account-related queries, improving both efficiency and user satisfaction.
# : 0.9999999999999998, Education has also benefited from AI-driven platforms.: 0.3571428571428571, Universities like IIT Bombay and IIT Delhi
# are incorporating data science and AI courses into their curricula to prepare students for future job
# markets.: 1.4285714285714282, Online learning platforms such as Coursera, edX, and Udemy provide personalized
# learning experiences by analyzing user behavior and recommending relevant courses.: 1.214285714285714, As a result,
# students from remote areas of Rajasthan and Uttar Pradesh now have access to high-quality
# educational resources.
# : 0.7857142857142856, Despite these benefits, the rise of AI has raised several ethical and social concerns.: 0.5714285714285714, Experts from
# organizations like the World Economic Forum (WEF) and UNESCO have warned about issues
# related to data privacy, algorithmic bias, and job displacement.: 1.4999999999999996, In 2023, a report published by
# UNESCO emphasized the need for transparent and fair AI systems to ensure that technology
# benefits society as a whole.
# : 1.1428571428571426, Governments around the world are responding by introducing regulations and policies.: 0.4285714285714285, The
# European Union proposed the AI Act, aiming to regulate high-risk AI applications, while the
# Government of India announced initiatives such as Digital India and National AI Strategy to promote
# responsible AI development.: 0.9285714285714284, Policymakers believe that a balanced approach can foster innovation
# while protecting citizens' rights.
# : 0.5714285714285713, Looking ahead, the future of AI appears promising yet challenging.: 0.4285714285714285, Researchers predict that AI will
# continue to evolve, enabling smarter cities, autonomous vehicles, and advanced healthcare
# systems.: 0.9999999999999999, However, collaboration between governments, private organizations, and academic
# institutions will be essential to address ethical challenges and ensure sustainable growth.
# : 1.2857142857142854, Ultimately, AI is not just a technological revolution but a societal transformation that will shape the
# way humans live and work in the decades to come.
# : 0.857142857142857}

# %% [markdown]
# #Getting the summary

# %%
summary=nlargest(n=int(select_length),iterable=sentence_score,key=sentence_score.get)

# %%
summary
# Out:
# [Experts from
#  organizations like the World Economic Forum (WEF) and UNESCO have warned about issues
#  related to data privacy, algorithmic bias, and job displacement.,
#  Universities like IIT Bombay and IIT Delhi
#  are incorporating data science and AI courses into their curricula to prepare students for future job
#  markets.,
#  Companies such as Google, Microsoft, and Amazon have invested billions of dollars into
#  research and development to improve intelligent systems that can learn from data and make
#  decisions with minimal human intervention.,
#  However, collaboration between governments, private organizations, and academic
#  institutions will be essential to address ethical challenges and ensure sustainable growth.,
#  Online learning platforms such as Coursera, edX, and Udemy provide personalized
#  learning experiences by analyzing user behavior and recommending relevant courses.]

# %%
#Combine these sentences together
final_summary=[word.text for word in summary]

# %%
final_summary
# Out:
# ['Experts from\norganizations like the World Economic Forum (WEF) and UNESCO have warned about issues\nrelated to data privacy, algorithmic bias, and job displacement.',
#  'Universities like IIT Bombay and IIT Delhi\nare incorporating data science and AI courses into their curricula to prepare students for future job\nmarkets.',
#  'Companies such as Google, Microsoft, and Amazon have invested billions of dollars into\nresearch and development to improve intelligent systems that can learn from data and make\ndecisions with minimal human intervention.',
#  'However, collaboration between governments, private organizations, and academic\ninstitutions will be essential to address ethical challenges and ensure sustainable growth.\n',
#  'Online learning platforms such as Coursera, edX, and Udemy provide personalized\nlearning experiences by analyzing user behavior and recommending relevant courses.']

# %%
summary=' '.join(final_summary)

# %%
print(summary)
# Out:
# Experts from
# organizations like the World Economic Forum (WEF) and UNESCO have warned about issues
# related to data privacy, algorithmic bias, and job displacement. Universities like IIT Bombay and IIT Delhi
# are incorporating data science and AI courses into their curricula to prepare students for future job
# markets. Companies such as Google, Microsoft, and Amazon have invested billions of dollars into
# research and development to improve intelligent systems that can learn from data and make
# decisions with minimal human intervention. However, collaboration between governments, private organizations, and academic
# institutions will be essential to address ethical challenges and ensure sustainable growth.
#  Online learning platforms such as Coursera, edX, and Udemy provide personalized
# learning experiences by analyzing user behavior and recommending relevant courses.

# %%
from spacy import displacy

# Visualize the named entities
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recent years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artificial Intelligence (AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) has transformed the way organizations operate across the<br>globe. Companies such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have invested
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     billions of dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  into<br>research and development to improve intelligent systems that can learn from data and make<br>decisions with minimal human intervention. These advancements have led to the rapid growth of<br>fields like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Machine Learning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Natural Language Processing, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer Vision
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br>In
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the adoption of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has accelerated significantly, particularly in sectors such as healthcare,<br>education, and finance. For example, hospitals in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bangalore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  now use
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -powered<br>diagnostic tools to detect diseases like cancer at an early stage. Similarly, banks such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     State
# Bank of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SBI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HDFC Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have deployed chatbots to assist customers with<br>account-related queries, improving both efficiency and user satisfaction.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Education
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has also benefited from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -driven platforms. Universities like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IIT Bombay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IIT Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>are incorporating data science and AI courses into their curricula to prepare students for future job<br>markets. Online learning platforms such as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coursera
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , edX, and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Udemy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  provide personalized<br>learning experiences by analyzing user behavior and recommending relevant courses. As a result,<br>students from remote areas of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6
