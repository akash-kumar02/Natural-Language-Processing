# %%
# 1. Create a Doc object from the file peterrabbit.txt
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
with open(r"/content/peterrabbit.txt",'r',encoding='utf-8') as f:
  d=f.read()
  doc=nlp(d)

# %%
# 2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.

# %%
sentences=list(doc.sents)

# %%
token_test=sentences[2]

# %%
print('3rd Sentence:',token_test)
# Out:
# 3rd Sentence: They lived with their Mother in a sand-bank, underneath the root of a
# very big fir-tree.

# %%
for token in token_test:
  print(f"Token {token.text:<10} POS {token.pos_:<10} TAG {token.tag_:<10} DESCRIPTION {spacy.explain(token.tag_)}")
# Out:
# Token They       POS PRON       TAG PRP        DESCRIPTION pronoun, personal
# Token lived      POS VERB       TAG VBD        DESCRIPTION verb, past tense
# Token with       POS ADP        TAG IN         DESCRIPTION conjunction, subordinating or preposition
# Token their      POS PRON       TAG PRP$       DESCRIPTION pronoun, possessive
# Token Mother     POS PROPN      TAG NNP        DESCRIPTION noun, proper singular
# Token in         POS ADP        TAG IN         DESCRIPTION conjunction, subordinating or preposition
# Token a          POS DET        TAG DT         DESCRIPTION determiner
# Token sand       POS NOUN       TAG NN         DESCRIPTION noun, singular or mass
# Token -          POS PUNCT      TAG HYPH       DESCRIPTION punctuation mark, hyphen
# Token bank       POS NOUN       TAG NN         DESCRIPTION noun, singular or mass
# Token ,          POS PUNCT      TAG ,          DESCRIPTION punctuation mark, comma
# Token underneath POS ADP        TAG IN         DESCRIPTION conjunction, subordinating or preposition
# Token the        POS DET        TAG DT         DESCRIPTION determiner
# Token root       POS NOUN       TAG NN         DESCRIPTION noun, singular or mass
# Token of         POS ADP        TAG IN         DESCRIPTION conjunction, subordinating or preposition
# Token a          POS DET        TAG DT         DESCRIPTION determiner
# Token
#           POS SPACE      TAG _SP        DESCRIPTION whitespace
# Token very       POS ADV        TAG RB         DESCRIPTION adverb
# Token big        POS ADJ        TAG JJ         DESCRIPTION adjective (English), other noun-modifier (Chinese)
# Token fir        POS NOUN       TAG NN         DESCRIPTION noun, singular or mass
# Token -          POS PUNCT      TAG HYPH       DESCRIPTION punctuation mark, hyphen
# Token tree       POS NOUN       TAG NN         DESCRIPTION noun, singular or mass
# Token .          POS PUNCT      TAG .          DESCRIPTION punctuation mark, sentence closer
# Token
#
#          POS SPACE      TAG _SP        DESCRIPTION whitespace

# %%
# 3. Provide a frequency list of POS tags from the entire document

# %%
import spacy
from collections import Counter

# %%
pos=Counter([token.pos_ for token in doc])

# %%
print("Frequency of pos tags:/n")
for p,freq in pos.items():
  print(f"{p: <10}: {freq}")
# Out:
# Frequency of pos tags:/n
# DET       : 90
# PROPN     : 75
# ADP       : 124
# PUNCT     : 172
# NUM       : 8
# SPACE     : 99
# ADV       : 65
# SCONJ     : 20
# NOUN      : 173
# PRON      : 108
# VERB      : 131
# ADJ       : 54
# CCONJ     : 61
# AUX       : 50
# PART      : 28

# %%
# 4. CHALLENGE: What percentage of tokens are nouns?

# %%
tokens = [token for token in doc if not token.is_punct and not token.is_space]

# %%
noun = [token for token in tokens if token.pos_ in ["NOUN", "PROPN"]]

# %%
percentage = (len(noun) / len(tokens)) * 100 if tokens else 0

# %%
print(f"Nouns percentage: {percentage:.2f}%")
# Out:
# Nouns percentage: 25.08%

# %%
# 5. Display the Dependency Parse for the third sentence.

# %%
d_parse=list(doc.sents)

# %%
token_test=sentences[2]

# %%
print('3rd Sentence:',token_test)
# Out:
# 3rd Sentence: They lived with their Mother in a sand-bank, underneath the root of a
# very big fir-tree.

# %%
for token in token_test:
  print(f'{token.text:12} {token.dep_:<10} {token.pos_:<10} {token.head.text:<10}')
# Out:
# They         nsubj      PRON       lived
# lived        ROOT       VERB       lived
# with         prep       ADP        lived
# their        poss       PRON       Mother
# Mother       pobj       PROPN      with
# in           prep       ADP        lived
# a            det        DET        bank
# sand         compound   NOUN       bank
# -            punct      PUNCT      bank
# bank         pobj       NOUN       in
# ,            punct      PUNCT      bank
# underneath   prep       ADP        bank
# the          det        DET        root
# root         pobj       NOUN       underneath
# of           prep       ADP        root
# a            det        DET        tree
#
#             dep        SPACE      a
# very         advmod     ADV        big
# big          amod       ADJ        tree
# fir          compound   NOUN       tree
# -            punct      PUNCT      tree
# tree         pobj       NOUN       of
# .            punct      PUNCT      lived
#
#
#            dep        SPACE      .

# %%
from spacy import displacy
displacy.render(token_test,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e51b8bb9be1345798d1675c7fd89cd0e-0" class="displacy" width="3550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Mother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">sand-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">bank,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">underneath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">fir-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">tree.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-2" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-3" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,354.0 L748.0,342.0 732.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-4" stroke-width="2px" d="M245,352.0 C245,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e51b8bb9be1345798d1675c7fd89cd0e-0-4" class="displacy-label" startOffset="50%" side="l

# %%
# 6. Show the first two named entities from Beatrix Potter's The Tale of Peter Rabbit

# %%
ent=[(ent.text,ent.label_) for ent in doc.ents]
print('First two named entities')
for ent_text,ent_label in ent[:2]:
  print(f'{ent_text} |{ent_label}')
# Out:
# First two named entities
# The Tale of Peter Rabbit |WORK_OF_ART
# Beatrix Potter |PERSON

# %%
# 7. How many sentences are contained in The Tale of Peter Rabbit?

# %%
sentences=list(doc.sents)

# %%
print("No. of sentences:",len(sentences))
# Out:
# No. of sentences: 57

# %%
for i, sent in enumerate(sentences[:3], start=1):
    print(f"Sentence {i}= {sent.text.strip()}")
# Out:
# Sentence 1= The Tale of Peter Rabbit, by Beatrix Potter (1902).
# Sentence 2= Once upon a time there were four little Rabbits, and their names
# were--
#
#           Flopsy,
#        Mopsy,
#    Cotton-tail,
# and Peter.
# Sentence 3= They lived with their Mother in a sand-bank, underneath the root of a
# very big fir-tree.

# %%
# 8. CHALLENGE: How many sentences contain named entities?

# %%
sentences = list(doc.sents)
entities = [sent for sent in sentences if any(ent.start >= sent.start and ent.end <= sent.end for ent in doc.ents)]

# %%
print(f"Total sentences: {len(sentences)}")
print(f"Sentences containing named entities: {len(entities)}")
# Out:
# Total sentences: 57
# Sentences containing named entities: 38

# %%
for sent in entities:
    ents = [ent.text for ent in doc.ents if ent.start >= sent.start and ent.end <= sent.end]
    print(f"\nSentence: {sent.text.strip()}")
    print(f"Named Entities: {ents}")
# Out:
# Sentence: The Tale of Peter Rabbit, by Beatrix Potter (1902).
# Named Entities: ['The Tale of Peter Rabbit', 'Beatrix Potter', '1902']
#
# Sentence: Once upon a time there were four little Rabbits, and their names
# were--
#
#           Flopsy,
#        Mopsy,
#    Cotton-tail,
# and Peter.
# Named Entities: ['four', 'Mopsy', 'Cotton-tail', 'Peter']
#
# Sentence: 'Now my dears,' said old Mrs. Rabbit one morning, 'you may go into
# the fields or down the lane, but don't go into Mr. McGregor's garden:
# your Father had an accident there; he was put in a pie by Mrs.
# McGregor.'
#
# 'Now run along, and don't get into mischief.
# Named Entities: ['Rabbit', 'one morning', 'McGregor', 'McGregor']
#
# Sentence: Then old Mrs. Rabbit took a basket and her umbrella, and went through
# the wood to the baker's.
# Named Entities: ['Rabbit']
#
# Sentence: She bought a loaf of brown bread and five
# currant buns.
# Named Entities: ['five']
#
# Sentence: Flopsy, Mopsy, and Cottontail, who were good little bunnies, went
# down the lane to gather blackberries:
# Named Entities: ['Flopsy', 'Mopsy', 'Cottontail']
#
# Sentence: But Peter, who was very naughty, ran straight away to Mr. McGregor's
# garden, and squeezed under the gate!
# Named Entities: ['Peter', 'McGregor']
#
# Sentence: First he ate some lettuces and some French beans; and then he ate
# some radishes;
# Named Entities: ['First', 'French']
#
# Sentence: But round the end of a cucumber frame, whom should he meet but Mr.
# McGregor!
# Named Entities: ['McGregor']
#
# Sentence: Mr. McGregor was on his hands and knees planting out young cabbages,
# but he jumped up and ran after Peter, waving a rake and calling out,
# 'Stop thief!'
# Named Entities: ['McGregor', 'Peter']
#
# Sentence: Peter was most dreadfully frightened; he rushed all over the garden,
# for he had forgotten the way back to the gate.
# Named Entities: ['Peter']
#
# Sentence: He lost one of his shoes among the cabbages, and the other shoe
# amongst the potatoes.
# Named Entities: ['one']
#
# Sentence: After losing them, he ran on four legs and went faster, so that I
# think he might have got away altogether if he had not unfortunately
# run into a gooseberry net, and got caught by the large buttons on his
# jacket.
# Named Entities: ['four']
#
# Sentence: Peter gave himself up for lost, and shed big tears; but his sobs were
# overheard by some friendly sparrows, who flew to him in great
# excitement, and implored him to exert himself.
# Named Entities: ['Peter']
#
# Sentence: Mr. McGregor came up with a sieve, which he intended to pop upon the
# top of Peter; but Peter wriggled out just in time, leaving his jacket
# behind him.
#
# And rushed into the tool-shed, and jumped into a can.
# Named Entities: ['McGregor', 'Peter', 'Peter']
#
# Sentence: Mr. McGregor was quite sure that Peter was somewhere in the
# tool-shed, perhaps hidden underneath a flower-pot.
# Named Entities: ['McGregor', 'Peter']
#
# Sentence: Presently Peter sneezed--'Kertyschoo!'
# Named Entities: ["Peter sneezed--'Kertyschoo"]
#
# Sentence: Mr. McGregor was after him in
# no time.
# Named Entities: ['McGregor']
#
# Sentence: And tried to put his foot upon Peter, who jumped out of a window,
# upsetting three plants.
# Named Entities: ['Peter', 'three']
#
# Sentence: The window was too small for Mr. McGregor, and
# he was tired of running after Peter.
# Named Entities: ['McGregor', 'Peter']
#
# Sentence: Peter sat down to rest; he was out of breath and trembling with
# fright, and he had not the least idea which way to go.
# Named Entities: ['Peter']
#
# Sentence: Peter asked her the way to
# the gate, but she had such a large pea in her mouth that she could not
# answer.
# Named Entities: ['Peter']
#
# Sentence: Peter began to cry.
# Named Entities: ['Peter']
#
# Sentence: Presently, he came to a pond where Mr.
# McGregor filled his water-cans.
# Named Entities: ['McGregor']
#
# Sentence: Peter thought it best to go away
# without speaking to her; he had heard about cats from his cousin,
# little Benjamin Bunny.
# Named Entities: ['Peter', 'Benjamin Bunny']
#
# Sentence: Peter scuttered underneath the bushes.
# Named Entities: ['Peter']
#
# Sentence: The first thing he saw was Mr. McGregor hoeing onions.
# Named Entities: ['first', 'McGregor']
#
# Sentence: His back was
# turned towards Peter, and beyond him was the gate!
# Named Entities: ['Peter']
#
# Sentence: Peter got down very quietly off the wheelbarrow; and started running
# as fast as he could go, along a straight walk behind some
# black-currant bushes.
# Named Entities: ['Peter']
#
# Sentence: Mr. McGregor caught sight of him at the corner, but Peter did not
# care.
# Named Entities: ['McGregor', 'Peter']
#
# Sentence: Mr. McGregor hung up the little jacket and the shoes for a scare-crow
# to frighten the blackbirds.
# Named Entities: ['McGregor']
#
# Sentence: Peter never stopped running or looked behind him till he got home to
# the big fir-tree.
# Named Entities: ['Peter']
#
# Sentence: It was the
# second little jacket and pair of shoes that Peter had lost in a
# fortnight!
# Named Entities: ['second', 'Peter']
#
# Sentence: I am sorry to say that Peter was not very well during the evening.
# Named Entities: ['Peter', 'the evening']
#
# Sentence: His mother put him to bed, and made some camomile tea; and she gave a
# dose of it to Peter!
# Named Entities: ['Peter']
#
# Sentence: 'One table-spoonful to be taken at bed-time.'
# Named Entities: ['One']
#
# Sentence: But Flopsy, Mopsy, and Cotton-tail had bread and milk and
# blackberries for supper.
# Named Entities: ['Flopsy', 'Mopsy', 'Cotton-tail']
#
# Sentence: THE END
# Named Entities: ['END']

# %%
# 9. Display the named entity visualization for list_of_sents[0] from the previous problem

# %%
l=list(doc.sents)

# %%
n_entity=l[0]
print("Sentence to visualise",n_entity.text)
# Out:
# Sentence to visualise The Tale of Peter Rabbit, by Beatrix Potter (1902).

# %%
displacy.render(n_entity,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).<br><br></div></span>
